# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from IPython.display import display

# %%
pd.set_option('display.max_columns', None)
WorldCupMatches = pd.read_csv('WorldCupMatches.csv')
WorldCupPlayers = pd.read_csv('WorldCupPlayers.csv')
WorldCups = pd.read_csv('WorldCups.csv')

# %%
display(WorldCupPlayers)
# Out:
#        RoundID    MatchID Team Initials               Coach Name Line-up  \
# 0          201       1096           FRA      CAUDRON Raoul (FRA)       S
# 1          201       1096           MEX         LUQUE Juan (MEX)       S
# 2          201       1096           FRA      CAUDRON Raoul (FRA)       S
# 3          201       1096           MEX         LUQUE Juan (MEX)       S
# 4          201       1096           FRA      CAUDRON Raoul (FRA)       S
# ...        ...        ...           ...                      ...     ...
# 37779   255959  300186501           ARG  SABELLA Alejandro (ARG)       N
# 37780   255959  300186501           GER       LOEW Joachim (GER)       N
# 37781   255959  300186501           ARG  SABELLA Alejandro (ARG)       N
# 37782   255959  300186501           GER       LOEW Joachim (GER)       N
# 37783   255959  300186501           ARG  SABELLA Alejandro (ARG)       N
#
#        Shirt Number       Player Name Position       Event
# ...

# %%
display(WorldCupMatches)
# Out:
#         Year              Datetime    Stage         Stadium         City  \
# 0     1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1     1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2     1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3     1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4     1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
# ...      ...                   ...      ...             ...          ...
# 4567     NaN                   NaN      NaN             NaN          NaN
# 4568     NaN                   NaN      NaN             NaN          NaN
# 4569     NaN                   NaN      NaN             NaN          NaN
# 4570     NaN                   NaN      NaN             NaN          NaN
# 4571     NaN                   NaN      NaN             NaN          NaN
#
#      Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# ...

# %%
display(WorldCups)
# Out:
#     Year       Country      Winner      Runners-Up        Third  \
# 0   1930       Uruguay     Uruguay       Argentina          USA
# 1   1934         Italy       Italy  Czechoslovakia      Germany
# 2   1938        France       Italy         Hungary       Brazil
# 3   1950        Brazil     Uruguay          Brazil       Sweden
# 4   1954   Switzerland  Germany FR         Hungary      Austria
# 5   1958        Sweden      Brazil          Sweden       France
# 6   1962         Chile      Brazil  Czechoslovakia        Chile
# 7   1966       England     England      Germany FR     Portugal
# 8   1970        Mexico      Brazil           Italy   Germany FR
# 9   1974       Germany  Germany FR     Netherlands       Poland
# 10  1978     Argentina   Argentina     Netherlands       Brazil
# 11  1982         Spain       Italy      Germany FR       Poland
# 12  1986        Mexico   Argentina      Germany FR       France
# 13  1990         Italy  Germany FR       Argentina        Italy
# ...

# %%
invalid_years = WorldCupMatches['Year'][WorldCupMatches['Year'].isna()]   #Identificar los valores no válidos
print(invalid_years)
# Out:
# 852    NaN
# 853    NaN
# 854    NaN
# 855    NaN
# 856    NaN
#         ..
# 4567   NaN
# 4568   NaN
# 4569   NaN
# 4570   NaN
# 4571   NaN
# Name: Year, Length: 3720, dtype: float64

# %%
WorldCupMatches = WorldCupMatches.dropna(subset=['Year'])   #Eliminar las filas con valores no válidos

# %%
#WorldCupMatches['Year'].fillna(0, inplace=True)   # Rellena los valores faltantes con algún valor específico

# %%
WorldCupMatches.tail(5)   # Muestra las últimas filas del dataset una vez realizada la limpieza de datos y eliminar datos no validos
# Out:
#        Year              Datetime                     Stage  \
# 847  2014.0  05 Jul 2014 - 17:00             Quarter-finals
# 848  2014.0  08 Jul 2014 - 17:00                Semi-finals
# 849  2014.0  09 Jul 2014 - 17:00                Semi-finals
# 850  2014.0  12 Jul 2014 - 17:00   Play-off for third place
# 851  2014.0  13 Jul 2014 - 16:00                      Final
#
#                  Stadium             City Home Team Name  Home Team Goals  \
# 847     Arena Fonte Nova        Salvador     Netherlands              0.0
# 848     Estadio Mineirao  Belo Horizonte          Brazil              1.0
# 849   Arena de Sao Paulo       Sao Paulo     Netherlands              0.0
# 850     Estadio Nacional        Brasilia          Brazil              0.0
# 851  Estadio do Maracana  Rio De Janeiro         Germany              1.0
#
#      Away Team Goals Away Team Name                         Win conditions  \
# 847              0.0     Costa Rica  Netherlands win on penalties (4 - 3)
# ...

# %%
# Goles Locales anotados en cada mundial
WorldCupMatches['Year'] = WorldCupMatches['Year'].astype(int)   # Convertir los valores de 'Year' a enteros
plt.plot(WorldCupMatches['Year'], WorldCupMatches['Home Team Goals'])   #Gráfica dos columnas
#plt.xticks(range(WorldCups['Year'].min(), WorldCups['Year'].max() + 1, 6))   # Aquí estoy configurando el espaciado para que se muestren los años cada 6 años
plt.xticks(WorldCups['Year'][::1])   # Aquí estoy configurando el espaciado para que se muestren los años iterando cada valor
plt.xticks(rotation=45)   # Rotar los ticks del eje x en 45 grados
plt.show()

# %%
#Goles anotados en cada mundial
WorldCups['Year'] = WorldCups['Year'].astype(int)   # Convierte la columna 'Year' a valores enteros
plt.figure(figsize=(8,5))   # Establece la gráfica con una dimensión de 8 pulgadas de ancho por 5 de alto
plt.title('Goles anotados durante cada Mundial', fontdict={'fontweight':'bold', 'fontsize':18})   # Pone in título a la gráfica
plt.plot(WorldCups['Year'], WorldCups['GoalsScored'], 'b.-', label='Goles Anotados')   # Gráfica dos columnas
plt.plot(WorldCups['Year'], WorldCups['MatchesPlayed'], label='Partidos Jugados')
plt.xlabel('Años')
plt.ylabel('Cantidad')
plt.legend()
plt.xticks(WorldCups['Year'][::1])   # Aquí estoy configurando el espaciado para que se muestren los años iterando cada valor
plt.xticks(rotation=45)   # Rotar los ticks del eje x en 45 grados
plt.savefig('goles.png', dpi=300)   # Guarda la gráfica como imagen
plt.show()

# %%
WorldCupPlayers.head(5)
# Out:
#    RoundID  MatchID Team Initials           Coach Name Line-up  Shirt Number  \
# 0      201     1096           FRA  CAUDRON Raoul (FRA)       S             0
# 1      201     1096           MEX     LUQUE Juan (MEX)       S             0
# 2      201     1096           FRA  CAUDRON Raoul (FRA)       S             0
# 3      201     1096           MEX     LUQUE Juan (MEX)       S             0
# 4      201     1096           FRA  CAUDRON Raoul (FRA)       S             0
#
#         Player Name Position Event
# 0       Alex THEPOT       GK   NaN
# 1   Oscar BONFIGLIO       GK   NaN
# 2  Marcel LANGILLER      NaN  G40'
# 3      Juan CARRENO      NaN  G70'
# 4   Ernest LIBERATI      NaN   NaN

# %%
fifa = pd.read_csv('FIFA19FullData.csv')
fifa.head(5)
# Out:
#                 Name Nationality National_Position  National_Kit  \
# 0  Cristiano Ronaldo    Portugal                LS           7.0
# 1       Lionel Messi   Argentina                RW          10.0
# 2             Neymar      Brazil                LW          10.0
# 3        Luis Suárez     Uruguay                LS           9.0
# 4       Manuel Neuer     Germany                GK           1.0
#
#            Club Club_Position  Club_Kit Club_Joining  Contract_Expiry  Rating  \
# 0   Real Madrid            LW       7.0   07/01/2009           2021.0      94
# 1  FC Barcelona            RW      10.0   07/01/2004           2018.0      93
# 2  FC Barcelona            LW      11.0   07/01/2013           2021.0      92
# 3  FC Barcelona            ST       9.0   07/11/2014           2021.0      92
# 4     FC Bayern            GK       1.0   07/01/2011           2021.0      92
#
#    Height Weight Preffered_Foot  Birth_Date  Age Preffered_Position  \
# ...

# %%
#2 Gráficas (Histograma y Barras)
fig, axs = plt.subplots(2, 1, figsize=(14, 10))   # Crea la figura y los subplots para mostrar 2 gráficos

# Histograma para la columna 'Rating' de fifa
axs[0].hist(fifa['Rating'], bins=100, color='r')   #Crea un histograma con 100 intervalos, en color rojo
axs[0].set_title('Histograma de Ratings en FIFA', fontdict={'fontweight':'bold', 'fontsize':18})
axs[0].set_xlabel('Rating de habilidad')
axs[0].set_ylabel('Número de jugadores')
plt.setp(axs[0].xaxis.get_majorticklabels(), rotation=45)   # Rota las etiquetas del eje x en el primer subplot para mejorar la legibilidad
axs[0].set_xticks(range(int(fifa['Rating'].min()), int(fifa['Rating'].max()) + 1, 2))   # Establecer los ticks del eje x para que estén separados por intervalos de 2 unidades en la primera gráfica

# Gráfica de barras para la columna 'Team Initials' de WorldCupPlayers
axs[1].bar(WorldCupPlayers['Team Initials'].unique(), WorldCupPlayers['Team Initials'].value_counts())   #Crea una gráfica de barras usando valores sin repetir para los países
axs[1].set_title('Gráfica de barras de la nacionalidad de los jugadores en Copa del Mundo', fontdict={'fontweight':'bold', 'fontsize':18})
axs[1].set_xlabel('Países participantes')
axs[1].set_ylabel('Número de jugadores')
plt.setp(axs[1].xaxis.get_majorticklabels(), rotation=90, ha='right')   # Rota etiquetas x 90 grados y coloca el extremo derecho de cada etiqueta para coincir con la posición de las marcas en el eje x 

plt.tight_layout()   # Ajusta el espacio entre los subplots
plt.show()   # Muestra las gráficas

# %%
#Gráfica de pastel
left = fifa.loc[fifa['Preffered_Foot'] == 'Left'].count().iloc[0]
right = fifa.loc[fifa['Preffered_Foot'] == 'Right'].count().iloc[0]

labels = ['Left', 'Right']
colors = ['#31f700', '#ad00f7']   #Establece los colores en valor Hexadecimal

plt.pie([left,right], labels=labels, colors=colors, autopct='%.2f %%')   #Muestra el gráfico de pastel con un valor porcentual de 2 decimales 
plt.title('Pie dominante')
plt.show()

# %%
fifa.head(10)
# Out:
#                  Name Nationality National_Position  National_Kit  \
# 0   Cristiano Ronaldo    Portugal                LS           7.0
# 1        Lionel Messi   Argentina                RW          10.0
# 2              Neymar      Brazil                LW          10.0
# 3         Luis Suárez     Uruguay                LS           9.0
# 4        Manuel Neuer     Germany                GK           1.0
# 5              De Gea       Spain                GK           1.0
# 6  Robert Lewandowski      Poland                LS           9.0
# 7         Gareth Bale       Wales                RS          11.0
# 8  Zlatan Ibrahimović      Sweden               NaN           NaN
# 9    Thibaut Courtois     Belgium                GK           1.0
#
#              Club Club_Position  Club_Kit Club_Joining  Contract_Expiry  \
# 0     Real Madrid            LW       7.0   07/01/2009           2021.0
# 1    FC Barcelona            RW      10.0   07/01/2004           2018.0
# ...

# %%
#Convertir la masa corporal de string a valores númericos
new_weights = []   # Crea una lista para almacenar los nuevos valores de peso

# Itera sobre cada elemento `x` en la columna 'Weight' y aplica la lógica de conversión
for x in fifa.Weight:
    if type(x) == str:   # Si el elemento es una cadena (str), elimina los caracteres 'kg' y convierte a entero
        new_weight = int(x.strip('kg'))

    else:   # Si no es una cadena, mantén el valor sin cambios
        new_weight = x
    new_weights.append(new_weight)   # Agrega el nuevo valor de peso a la lista

# Asigna la lista de nuevos pesos a la columna 'Weight' del DataFrame `fifa`
fifa.Weight = new_weights

print(fifa.Weight[0])
print(type(fifa.Weight[0]))
# Out:
# 80
# <class 'numpy.int64'>

# %%
#Clasifica los jugadores por pesos en kg
light = fifa.loc[fifa.Weight < 60].count().iloc[0]
light_medium = fifa.loc[(fifa.Weight >= 60) & (fifa.Weight < 75)].count().iloc[0]
medium = fifa.loc[(fifa.Weight >= 75) & (fifa.Weight < 85)].count().iloc[0]
medium_heavy = fifa.loc[(fifa.Weight >= 85) & (fifa.Weight < 95)].count().iloc[0]
heavy = fifa.loc[fifa.Weight > 95].count().iloc[0]

weights = [light, light_medium, medium, medium_heavy, heavy]
labels = ['muy delgado', 'delgado', 'intermedio', 'pesado', 'muy pesado']
explode = (0, 0, 0, .2, 1)
plt.style.use('ggplot')   #Cambia los colres usados por default para la gráfica
plt.pie(weights, labels=labels, autopct='%.2f %%', pctdistance=0.8, explode=explode)   # Crea una gráfica de pastel desplazando los porcentajes a la orilla y 
plt.title('Masa corporal de los jugadores')
plt.show()

# %%
unique_nationalities = fifa['Nationality'].unique()
print(unique_nationalities)
# Out:
# ['Portugal' 'Argentina' 'Brazil' 'Uruguay' 'Germany' 'Spain' 'Poland'
#  'Wales' 'Sweden' 'Belgium' 'Croatia' 'France' 'Chile' 'Italy'
#  'Czech Republic' 'Slovenia' 'Colombia' 'Gabon' 'Netherlands' 'Austria'
#  'Armenia' 'England' 'Costa Rica' 'Denmark' 'Bosnia Herzegovina' 'Greece'
#  'Slovakia' 'Algeria' 'Serbia' 'Morocco' 'Turkey' 'Ivory Coast' 'Senegal'
#  'Cameroon' 'Switzerland' 'Egypt' 'Montenegro' 'Ukraine' 'Japan' 'Iceland'
#  'Republic of Ireland' 'Mexico' 'Ecuador' 'Nigeria' 'Russia' 'DR Congo'
#  'Finland' 'Venezuela' 'Norway' 'United States' 'Ghana' 'Guinea'
#  'New Zealand' 'Uzbekistan' 'Canada' 'Romania' 'Syria' 'Albania'
#  'Korea Republic' 'Tunisia' 'Cuba' 'Kenya' 'Northern Ireland' 'Peru'
#  'Paraguay' 'Australia' 'Mozambique' 'Bulgaria' 'Hungary' 'Scotland'
#  'Estonia' 'Angola' 'Iran' 'Cape Verde' 'Georgia' 'Burkina Faso'
#  'South Africa' 'Lithuania' 'Jamaica' 'Togo' 'Mali' 'Israel' 'Bolivia'
# ...

# %%
Portugal = fifa.loc[fifa['Nationality'] == 'Portugal'].count().iloc[0]
Portugal
# Out:
# 360

# %%
unique_nationalities = fifa['Nationality'].unique()   # Obtiene todas las nacionalidades únicas

for nationality in unique_nationalities:
    count_players = fifa.loc[fifa['Nationality'] == nationality].count().iloc[0]
    print(f"{nationality}: {count_players}")
# Out:
# Portugal: 360
# Argentina: 1097
# Brazil: 921
# Uruguay: 153
# Germany: 689
# Spain: 1008
# Poland: 328
# Wales: 122
# Sweden: 378
# Belgium: 265
# Croatia: 116
# France: 974
# Chile: 398
# Italy: 751
# Czech Republic: 57
# Slovenia: 58
# Colombia: 592
# Gabon: 15
# Netherlands: 426
# Austria: 266
# Armenia: 8
# England: 1618
# Costa Rica: 30
# Denmark: 342
# Bosnia Herzegovina: 52
# Greece: 86
# Slovakia: 61
# Algeria: 50
# Serbia: 136
# Morocco: 74
# Turkey: 292
# Ivory Coast: 90
# Senegal: 119
# Cameroon: 96
# Switzerland: 210
# Egypt: 30
# Montenegro: 23
# Ukraine: 59
# Japan: 471
# Iceland: 47
# Republic of Ireland: 442
# Mexico: 341
# Ecuador: 34
# Nigeria: 122
# Russia: 309
# DR Congo: 58
# Finland: 60
# Venezuela: 42
# Norway: 342
# United States: 332
# Ghana: 119
# Guinea: 34
# New Zealand: 30
# Uzbekistan: 3
# Canada: 59
# Romania: 61
# Syria: 5
# Albania: 37
# Korea Republic: 321
# Tunisia: 35
# Cuba: 2
# Kenya: 6
# Northern Ireland: 83
# Peru: 34
# Paraguay: 75
# ...

# %%
unique_nationalities = fifa['Nationality'].unique()   # Obtiene todas las nacionalidades únicas

player_counts = []   # Lista para almacenar el número de jugadores por nacionalidad

# Itera sobre cada nacionalidad y cuenta el número de jugadores
for nationality in unique_nationalities:
    count_players = fifa.loc[fifa['Nationality'] == nationality].count().iloc[0]
    player_counts.append(count_players)

explode = tuple(np.full(160, 2))

# Configura el gráfico de pastel
plt.figure(figsize=(10, 10))
plt.pie(player_counts, labels=unique_nationalities, autopct='%1.1f',pctdistance=0.8, explode=explode)
plt.title('Distribución de jugadores por nacionalidad', fontdict={'fontweight':'bold', 'fontsize':18})
plt.axis('equal')  # Asegura que el gráfico sea un círculo
plt.show()

# %%
plt.style.use('bmh')

barcelona = fifa.loc[fifa.Club == 'FC Barcelona']['Rating']
madrid = fifa.loc[fifa.Club =='Real Madrid']['Rating']

labels = ['FC Barcelona', 'Real Madrid']
boxes = plt.boxplot([barcelona, madrid], labels=labels, patch_artist=True, medianprops={'linewidth':2})
for box in boxes['boxes']:
        box.set(color='#000000', linewidth=2)   #Cambia el color de la orilla
        box.set(facecolor='#ffffff')   #Cambia el color de rellenado

plt.title('Comparativa de planteles')
plt.ylabel('Nivel de juego')
plt.show()   
# La linea roja representa la media
